# %% [markdown]
# <h1><center>EXPLORACIÓN DE DATOS</center></h1>
# <h1><center>DATA EXPLORATION</center></h1>

# %%
#Cargar Librerias
# load libraries
import pandas as pd
import missingno as msno

# %% [markdown]
# <h2>1. Municipio Buenaventura - (Municipality Buenaventura)</h2>
# <h3>1.1 Distribución de Valores Faltante - (Distribution of Missing Values)</h3>

# %%
df_c_c_btura_A_M = pd.read_excel(r"c.c. btura A M.xls")
msno.matrix(df_c_c_btura_A_M)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>1.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_BuenaVentura = df_c_c_btura_A_M.dropna(how="all",axis=1)
msno.matrix(df_BuenaVentura)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>1.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_BuenaVentura.iloc[:, 0:10] # Primeras diez columnas
# Out:
#      MATRICULA  PROPONENTE  ORGANIZACION  CATEGORIA EST-MATRICULA  EST_DATOS  \
# 0     S0000369         NaN            12          1            IA          6
# 1         9428         NaN             2          0            MI          8
# 2         9303         NaN             1          0            MI          6
# 3         9239         NaN             3          1            MI          8
# 4         9237         NaN             3          1            MI          8
# ...        ...         ...           ...        ...           ...        ...
# 4352     10804         NaN             3          1            MI          8
# 4353     10612         NaN             2          0            MI          8
# 4354     10515         NaN             1          0            MA          6
# 4355      1027         NaN             3          1            MI          8
# 4356     10122         NaN             3          1            MI          8
#
# ...

# %% [markdown]
# <h3>1.4 Columnas del DataFrame - Dataframe Columns</h3>

# %%
print(df_BuenaVentura.columns[0:11])
print("Columnas:",len(df_BuenaVentura.columns))
# Out:
# Index(['MATRICULA', 'PROPONENTE', 'ORGANIZACION', 'CATEGORIA', 'EST-MATRICULA',
#        'EST_DATOS', 'FECHA-NAC', 'CLASE-ID', 'IDENTIFICACION', 'GENERO',
#        'NIT'],
#       dtype='object')
# Columnas: 135

# %% [markdown]
# **MATRICULA** :
# <br>
# **PROPONENTE** :
# <br>
# **ORGANIZACION**:
# <br>
# **CATEGORIA**:
# <br>
# **EST-MATRICULA**:
# <br>
# **EST_DATOS**:
# <br>
# **FECHA-NAC**:
# <br>
# **CLASE-ID**:
# <br>
# **IDENTIFICACION**:
# <br>
# **GENERO**
# <br>
# **NIT**:
# <br>
# **FEC-MATRICULA**:
# <br>
# **FEC-RENOVACION**:
# <br>
# **ULT-ANO_REN**:
# <br>
# **FEC-CANCELACION**
# <br>
# **FEC-CONSTITUCION**
# <br>
# **FEC-DISOLUCION**
# <br>
# **FEC-LIQUIDACION**
# <br>
# **FEC-VIGENCIA**
# <br>
# **DIR-COMERCIAL**
# <br>
# **BARRIO-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **VIGILANCIA**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **TEL-NOTF-1**
# <br>
# **TEL-NOTF-2**
# <br>
# **EMAIL-NOTIFICACION**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **CANT-MUJERES**
# <br>
# **CANT-MUJERES-CAR-DIR**
# <br>
# **%-PART-MUJ**
# <br>
# **CIIU-TAM-EMPRESARIAL**
# <br>
# **ING-TAM-EMPRESARIAL**
# <br>
# **ANO-DATOS-TAM-EMPRESARIAL**
# <br>
# **FECHA-DATOS-TAM-EMPRESARIAL**
# <br>
# **LIBROS-COMERCIO**:
# <br>
# **CTR-EMBARGO**
# <br>
# **IMPORTA-EXPORTA**
# <br>
# **TIPO-LOCAL**
# <br>
# **UBICACION**
# <br>
# **CLA-ESPE-ESADL**
# <br>
# **CLA-ECON-SOLI**
# <br>
# **BEN-ART-7**
# <br>
# **BEN-LEY-1780(MAT)**
# <br>
# **CUM-LEY-1780(REN)**
# <br>
# **MAN-LEY-1780(REN)**
# <br>
# **REN-LEY-1780(REN)**
# <br>
# **TIPO-PROPIEDAD**
# <br>
# **BIC-LEY-1901-2018**:
# <br>
# **TAM-EMPRESA**
# <br>
# **PERSONAL**
# <br>
# **ACTIVO-CORRIENTE**
# <br>
# **ACTIVO-NO-CORRIENTE**
# <br>
# **ACTIVO-FIJO**
# <br>
# **ACTIVO-VALORIZ**
# <br>
# **ACTIVO-OTROS**
# <br>
# **ACTIVO-TOTAL**
# <br>
# **PASIVO-CORRIENTE**
# <br>
# **PASIVO-LRG-PLAZO**
# <br>
# **PASIVO-TOTAL**
# <br>
# **PATRIMONIO**
# <br>
# **PASIVO+PATRIM**
# <br>
# **ING-OPERACIONES**
# <br>
# **ING-NO-OPERACIONALES**
# <br>
# **GAS-OPERACIONALES**
# <br>
# **GAS-NO-OPERAC**
# <br>
# **COS-VEN**
# <br>
# **GAS-IMP**
# <br>
# **UTIL-OPERACIONAL**
# <br>
# **UTIL-NETA**
# <br>
# **GRUPO-NIIF**
# <br>
# **ANIO-DATOS**
# <br>
# **FECHA-DATOS**
# <br>
# **CAPITAL-AUTORIZ**
# <br>
# **CAPITAL-SUSCRITO**
# <br>
# **CAPITAL-PAGADO**
# <br>
# **CAPITAL-SOCIAL**
# <br>
# **APORTE-LABORAL**
# <br>
# **APORTE-LABORAL-ADI**
# <br>
# **APORTE-DINERO**
# <br>
# **APORTE-TRABAJO**
# <br>
# **APORTE-ACTIVOS**
# <br>
# **APORTE-TOTAL**
# <br>
# **VLR-ESTABLEC**
# <br>
# **PATRIM-ESADL**
# <br>
# **CANT-EST-BD**
# <br>
# **POR-NAL-PRI**
# <br>
# **POR-NAL-PUB**
# <br>
# **POR-NAL-TOT**
# <br>
# **POR-EXT-PRI**
# <br>
# **POR-EXT-PUB**
# <br>
# **POR-EXT-TOT**
# <br>
# **CTR-AFILIACION**
# <br>
# **ANIO-REN-AFIL**
# <br>
# **FEC-AFIL**
# <br>
# **FEC-ULT-PAG-AFIL**
# <br>
# **VAL-ULT-PAG-AFIL**
# <br>
# **FEC-ACTA-CAN-AFLIA**
# <br>
# **MAT-PROP**
# <br>
# **IDE-PROP**
# <br>
# **NIT-PROP**
# <br>
# **CAM-PROP**
# <br>
# **NOM-PROP**
# <br>
# **DIR-PROP**
# <br>
# **TEL-1-PROP**
# <br>
# **TEL-2-PROP**
# <br>
# **MUN-PROP**
# <br>
# **EMAIL-PROP**
# <br>
# **FEC-PAG-REN 2016**
# <br>
# **FEC-PAG-REN 2017**
# <br>
# **FEC-PAG-REN 2018**
# <br>
# **FEC-PAG-REN 2019**
# <br>
# **FEC-PAG-REN 2020**
# <br>
# **ACTI 2016**
# <br>
# **ACTI 2017**
# <br>
# **ACTI 2018**
# <br>
# **ACTI 2019*
# <br>
# **ACTI 2020**
# <br>
# **TIENELIBROS**
# <br>
# **NUM-SOCIOS**
# <br>
# **REP-LEGAL**
# <br>
# **NOM-REP-LEGAL**
# <br>
# **REP-LEGAL.1**
# <br>
# **NOM-REP-LEGAL.1**
# <br>
# **NUM-IDE-SUPLENTE**
# <br>
# **NOMBRE-SUPLENTE**
# <br>
# **NUM-IDE-SUPLENTE.1**
# <br>
# **NOMBRE-SUPLENTE.1**
# <br>
# **REVISORES**
# <br>
# **AUT-ENV**

# %% [markdown]
# <h2>2. Municipio Cartago- (Municipality Cartago)</h2>
# <h3>2.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_CARTAGOAM = pd.read_excel(r"CARTAGO A M.xlsx")
msno.matrix(df_CARTAGOAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>2.2 Eliminación de Datos NAN - (Removal of NAN Data)
# </h3>

# %%
df_CARTAGO = df_CARTAGOAM.dropna(how="all",axis=1)
msno.matrix(df_CARTAGO)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>2.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_CARTAGO.iloc[:, 0:9] # Primeras diez columnas
# Out:
#      MATRICULA  FEC-MATRICULA  FEC-RENOVACION  ULT-ANO_REN     DIR-COMERCIAL  \
# 0        99057       20200320        20200320         2020    CR 2 NRO 39-20
# 1        99003       20200316        20200316         2020    CR 7 NRO 14-05
# 2        98999       20200316        20200316         2020     CORR LA MARIA
# 3        98980       20200313        20200313         2020    CR 4 NRO 8-159
# 4        98975       20200312        20200312         2020   CL 16 NRO 3-101
# ..         ...            ...             ...          ...               ...
# 254      17324       19910522        20200220         2020  CR 6 NRO. 12-120
# 255      15905       19900517        20200113         2020    CR 5 NRO. 7-08
# 256      15787       19900426        20200108         2020   CR 3 NRO. 14-14
# 257      15160       19891010        20200102         2020    CR 9 NRO. 6-57
# 258      10931       19860204        20200116         2020   CR 9 NRO. 10-14
#
# ...

# %% [markdown]
# <h3>2.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_CARTAGO.columns)
print("Columnas:",len(df_CARTAGO.columns))
# Out:
# Index(['MATRICULA', 'FEC-MATRICULA', 'FEC-RENOVACION', 'ULT-ANO_REN',
#        'DIR-COMERCIAL', 'BARRIO-COMERCIAL', 'MUN-COMERCIAL', 'CIIU-1',
#        'CIIU-2', 'CIIU-3', 'CIIU-4', 'ACTIVIDAD', 'VLR-ESTABLEC.', 'IDE-PROP.',
#        'NIT-PROP.'],
#       dtype='object')
# Columnas: 15

# %% [markdown]
# **MATRICULA**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **BARRIO-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **VLR-ESTABLEC**
# <br>
# **IDE-PROP**
# <br>
# **NIT-PROP**
# <br>

# %% [markdown]
# <h2>3. Municipio Buga - (Municipality Buga)</h2>
# <h3>3.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_CCBUGAAM = pd.read_excel(r"CC BUGA A M.xlsx")
msno.matrix(df_CCBUGAAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>3.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_BUGA = df_CCBUGAAM.dropna(how="all",axis=1)
msno.matrix(df_BUGA)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>3.3 Visualización de Datos - (Data visualization)
# </h3>

# %%
df_BUGA.iloc[:, 0:6] # Primeras diez columnas
# Out:
#      MATRICULA  PROPONENTE  ORGANIZACION DESC_ORGANIZACION  CATEGORIA  \
# 0        11691         NaN             1   Persona Natural          0
# 1        12325         NaN             1   Persona Natural          0
# 2        12457         NaN             1   Persona Natural          0
# 3        12652         NaN             1   Persona Natural          0
# 4        12675         NaN             1   Persona Natural          0
# ..         ...         ...           ...               ...        ...
# 738      74296         NaN             1   Persona Natural          0
# 739      74298         NaN             1   Persona Natural          0
# 740       7464         NaN             1   Persona Natural          0
# 741       8388         NaN             1   Persona Natural          0
# 742       9468         NaN             1   Persona Natural          0
#
#          DESC_CATEGORIA
# 0    Personas Naturales
# 1    Personas Naturales
# 2    Personas Naturales
# 3    Personas Naturales
# ...

# %% [markdown]
# <h3>3.4 Columnas del DataFrame - (Dataframe Columns)
# </h3>

# %%
print(df_BUGA.columns)
print("Columnas:",len(df_BUGA.columns))
# Out:
# Index(['MATRICULA', 'PROPONENTE', 'ORGANIZACION', 'DESC_ORGANIZACION',
#        'CATEGORIA', 'DESC_CATEGORIA', 'EST-MATRICULA', 'ESTADO_MAT', 'NIT',
#        'MAT_ESTABLECIMIENTO', 'FEC_MATRICULA', 'FEC_RENOVACION', 'ULT-ANO_REN',
#        'DIR-COMERCIAL', 'MUN-COMERCIAL', 'TEL-COM-1', 'TEL-COM-2', 'TEL-COM-3',
#        'VIGILANCIA', 'DIR-NOTIFICACION', 'MUN-NOTIFICACION', 'CIIU-1',
#        'CIIU-2', 'CIIU-3', 'CIIU-4', 'PERSONAL', 'CTR-AFILIACION', 'REP-LEGAL',
#        'NOM-REP-LEGAL', 'TAM-EMPRESA', 'ACTIVO-TOTAL', 'PASIVO-TOTAL',
#        'PATRIMONIO', 'ING-OPERACIONES', 'ING-NO-OPERACIONALES',
#        'UTIL-OPERACIONAL', 'UTIL-NETA'],
#       dtype='object')
# Columnas: 37

# %% [markdown]
# **MATRICULA**
# <br>
# **PROPONENTE**
# <br>
# **ORGANIZACION**
# <br>
# **DESC_ORGANIZACION**
# <br>
# **CATEGORIA**
# <br>
# **DESC_CATEGORIA**
# <br>
# **EST-MATRICULA**
# <br>
# **ESTADO_MAT**
# <br>
# **NIT**
# <br>
# **MAT_ESTABLECIMIENTO**
# <br>
# **FEC_MATRICULA**
# <br>
# **FEC_RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **TEL-COM-1**
# <br>
# **TEL-COM-2**
# <br>
# **TEL-COM-3**
# <br>
# **VIGILANCIA**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **PERSONAL**
# <br>
# **CTR-AFILIACION**
# <br>
# **REP-LEGAL**
# <br>
# **NOM-REP-LEGAL**
# <br>
# **TAM-EMPRESA**
# <br>
# **ACTIVO-TOTAL**
# <br>
# **PASIVO-TOTAL**
# <br>
# **PATRIMONIO**
# <br>
# **ING-OPERACIONES**
# <br>
# **ING-NO-OPERACIONALES**
# <br>
# **UTIL-OPERACIONAL**
# <br>
# **UTIL-NETA**
# <br>

# %% [markdown]
# <h2>4 Municipio Cali - (Municipality Cali)</h2>
# <h3>4.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_ccCaliAM = pd.read_excel(r"cc Cali AM.xlsx")
msno.matrix(df_ccCaliAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>4.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_Cali = df_ccCaliAM.dropna(how="all",axis=1)
msno.matrix(df_Cali)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>4.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_Cali.iloc[:, 0:6] # Primeras diez columnas
# Out:
#       COD_CAMARA  NUM_CONSECUTIVO  NUM_INSCRITO  CODIGO_CIIU  SECUENCIA  \
# 0              8               57           165         4731        1.0
# 1              8              282           978         4731        1.0
# 2              8              282           978         4530        2.0
# 3              8              282           978         7120        3.0
# 4              8              282           978         4520        4.0
# ...          ...              ...           ...          ...        ...
# 4415           8          1170088       1083413         1011        3.0
# 4416           8          1170088       1083413         4659        4.0
# 4417           8          1170357       1083550         2011        1.0
# 4418           8          1170357       1083550         4773        2.0
# 4419           8          1170712       1083791         9200        1.0
#
#                                               DESC_CIIU
# ...

# %% [markdown]
# <h3>4.4 Columnas del DataFrame - (Dataframe Columns)
# </h3>

# %%
print(df_Cali.columns[0:11])
print("Columnas:",len(df_Cali.columns))
# Out:
# Index(['COD_CAMARA', 'NUM_CONSECUTIVO', 'NUM_INSCRITO', 'CODIGO_CIIU',
#        'SECUENCIA', 'DESC_CIIU', 'SECTOR', 'DESC_SECTOR', 'TIPO_REGISTRO',
#        'COD_TIPO_REGISTRO', 'CATEGORIA'],
#       dtype='object')
# Columnas: 70

# %% [markdown]
# **COD_CAMARA**
# <br>
# **NUM_CONSECUTIVO**
# <br>
# **NUM_INSCRITO**
# <br>
# **CODIGO_CIIU**
# <br>
# **SECUENCIA**
# <br>
# **DESC_CIIU**
# <br>
# **SECTOR**
# <br>
# **DESC_SECTOR**
# <br>
# **TIPO_REGISTRO**
# <br>
# **COD_TIPO_REGISTRO**
# <br>
# **CATEGORIA**
# <br>
# **NATURALEZA**
# <br>
# **COD_ESTADO**
# <br>
# **ESTADO**
# <br>
# **FECHA_REN_2016**
# <br>
# **FECHA_REN_2017**
# <br>
# **FECHA_REN_2018**
# <br>
# **FECHA_REN_2019**
# <br>
# **FECHA_REN_2020**
# <br>
# **NUM_ID**
# <br>
# **DIRECCION_COMERCIAL**
# <br>
# **BARRIO**
# <br>
# **CIUDAD**
# <br>
# **DEPARTAMENTO**
# <br>
# **DIRECCION_JURIDICO**
# <br>
# **ANO INFO FIN**
# <br>
# **FECHA_REGISTRO**
# <br>
# **GRUPONIIF**
# <br>
# **ACTIVO_CORRIENTE**
# <br>
# **ACTIVO_NO_CORRIENTE**
# <br>
# **ACTIVOS_FIJOS**
# <br>
# **ACTIVOS_FIJOS_NETOS**
# <br>
# **OTROS_ACTIVOS**
# <br>
# **VALORIZACIONES**
# <br>
# **TOT_ACTIVOS**
# <br>
# **PASIVO_CORRIENTE**
# <br>
# **PASIVO_LARGO_PLAZO**
# <br>
# **TOT_PASIVO**
# <br>
# **PATRIMONIO**
# <br>
# **TOT_PASIVO_PATRIMONIO**
# <br>
# **INGRESOS_OPERACIONALES**
# <br>
# **COSTO_VENTA**
# <br>
# **UTILILIDAD_BRUTA**
# <br>
# **GTOS_OPERERACION**
# <br>
# **GTOS_OPER_ADMIN**
# <br>
# **DEPRECNS_AMORTIZACIONES**
# <br>
# **UTILILIDAD_PERDIDA**
# <br>
# **INGRESOS_NO_OPERACIONALES**
# <br>
# **GASTOS_IMPUESTOS**
# <br>
# **PERSONAL_OCUPADO**
# <br>
# **PORCENT_EXTRANJERO**
# <br>
# **PORCENT_NAL**
# <br>
# **PORCENT_PAR_MUJERKT**
# <br>
# **PORCENT_PRIVEXT**
# <br>
# **PORCENT_PRIVNAL**
# <br>
# **PORCENT_PUBEXT**
# <br>
# **PORCENT_PUBNAL**
# <br>
# **NUMMUJERES**
# <br>
# **NUMTOTALMUJER_CD**
# <br>
# **NUMTOTALMUJERES**
# <br>
# **ESTBLCOMERCIALES**
# <br>
# **IND_ENVMSJCEL**
# <br>
# **IND_ENVMSJEMAIL**
# <br>
# **IND_BENEFICIO1780**
# <br>
# **IND_BENEFICIO1780MAT**
# <br>
# **IND_RENUNCIABEN1780**
# <br>
# **ESTADO_AFILIADO**
# <br>
# **FECHA_AFILIACION**
# <br>
# **FECHA_FIN_AFILIACION**
# <br>
# **VAL_ULT_CUOTA**<br>

# %% [markdown]
# <h2>5. Municipio Cartago PYG - (Municipality Cartago PYG)</h2>
# <h3>5.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_CCCARTAGOCONPYGAM = pd.read_excel(r"CC CARTAGO CON PYG A M.xlsx")
msno.matrix(df_CCCARTAGOCONPYGAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>5.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_CARTAGOCONPYG = df_CCCARTAGOCONPYGAM.dropna(how="all",axis=1)
msno.matrix(df_CARTAGOCONPYG)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>5.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_CARTAGOCONPYG.iloc[:, 0:10] # Primeras diez columnas
# Out:
#     MATRICULA EST-MATRICULA  CLASE-ID IDENTIFICACION          NIT  \
# 0       99696            MA         1       #eb3t#tr    #eb3t#tr#
# 1       99350            MA         1     hhh#rr#(3h  hhh#rr#(3hr
# 2       98986            MA         1     hhh#et&&#&  hhh#et&&#&r
# 3       98937            MA         1     hhh#:bhbht  hhh#:bhbhtb
# 4       98900            MA         1       h:3t#3b:    h:3t#3b:t
# ..        ...           ...       ...            ...          ...
# 81      84757            MA         1     hhh#ebbb&h  hhh#ebbb&h3
# 82      84487            MA         1       3trh(&:3    3trh(&:3b
# 83      84412            MA         1       ::r(thr:    ::r(thr:(
# 84      84371            MA         1        #&:e((:     #&:e((:&
# 85      83956            MA         1     hh#:&(h3b:  hh#:&(h3b:b
#
#     FEC-MATRICULA  FEC-RENOVACION  ULT-ANO_REN                  DIR-COMERCIAL  \
# 0        20200715        20200715         2020                 CR 4 NRO 12-04
# ...

# %% [markdown]
# <h3>5.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_CARTAGOCONPYG.columns)
print("Columnas:",len(df_CARTAGOCONPYG.columns))
# Out:
# Index(['MATRICULA', 'EST-MATRICULA', 'CLASE-ID', 'IDENTIFICACION', 'NIT',
#        'FEC-MATRICULA', 'FEC-RENOVACION', 'ULT-ANO_REN', 'DIR-COMERCIAL',
#        'BARRIO-COMERCIAL', 'MUN-COMERCIAL', 'DIR-NOTIFICACION',
#        'MUN-NOTIFICACION', 'CIIU-1', 'CIIU-2', 'CIIU-3', 'CIIU-4', 'ACTIVIDAD',
#        'PERSONAL', 'ACTIVO-TOTAL', 'ING-OPERACIONES', 'ING-NO-OPERACIONALES',
#        'GAS-OPERACIONALES', 'GAS-NO-OPERAC.', 'COS-VEN.', 'GAS-IMP.',
#        'UTIL-OPERACIONAL', 'UTIL-NETA', 'AUT-ENV'],
#       dtype='object')
# Columnas: 29

# %% [markdown]
# **MATRICULA**
# <br>
# **EST-MATRICULA**
# <br>
# **CLASE-ID**
# <br>
# **IDENTIFICACION**
# <br>
# **NIT**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **BARRIO-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **PERSONAL**
# <br>
# **ACTIVO-TOTAL**
# <br>
# **ING-OPERACIONES**
# <br>
# **ING-NO-OPERACIONALES**
# <br>
# **GAS-OPERACIONALES**
# <br>
# **GAS-NO-OPERAC**
# <br>
# **COS-VEN*
# <br>
# **GAS-IMP**
# <br>
# **UTIL-OPERACIONAL**
# <br>
# **UTIL-NETA**
# <br>
# **AUT-ENV**

# %% [markdown]
# <h2>6. Municipio Palmira - (Municipality Palmira)</h2>
# <h3>6.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_ccpalmiraAM = pd.read_excel(r"cc palmira A M.xlsx")
msno.matrix(df_ccpalmiraAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>6.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_palmira = df_ccpalmiraAM.dropna(how="all",axis=1)
msno.matrix(df_palmira)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>6.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_palmira.iloc[:, 0:7] # Primeras diez columnas
# Out:
#     CÁMARA DE COMERCIO DE PALMIRA    Unnamed: 1 Unnamed: 2     Unnamed: 4  \
# 0                       MATRICULA  ORGANIZACION  CATEGORIA  FEC-MATRICULA
# 1                           99871             2          0       20121002
# 2                           96006             2          0       20111004
# 3                           87254             3          3       20090217
# 4                             823             2          0       19700310
# ..                            ...           ...        ...            ...
# 758                        101182             2          0       20130124
# 759                        101012             2          0       20130104
# 760                        100952             2          0       20121220
# 761                        100887             2          0       20121130
# 762                        100783             2          0       20121126
#
#          Unnamed: 5   Unnamed: 6  \
# 0    FEC-RENOVACION  ULT-ANO_REN
# ...

# %% [markdown]
# <h3>6.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_palmira.columns)
print("Columnas:",len(df_palmira.columns))
# Out:
# Index(['CÁMARA DE COMERCIO DE PALMIRA', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30'],
#       dtype='object')
# Columnas: 23

# %% [markdown]
# **MATRICULA**
# <br>
# **ORGANIZACION**
# <br>
# **CATEGORIA**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **SECTOR**
# <br>
# **CIIU**
# <br>
# **ACTIVIDAD**
# <br>
# **VLR-ESTABLEC**
# <br>
# **MAT-PROP**
# <br>
# **IDE-PROP**
# <br>
# **NIT-PROP**
# <br>
# **CAM-PROP**
# <br>
# **DIR-PROP**

# %% [markdown]
# <h2>7. Municipio Sevilla - (Municipality Sevilla)</h2>
# <h3>7.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_CCSEVILLAAM = pd.read_excel(r"CC SEVILLA A M.xlsx")
msno.matrix(df_CCSEVILLAAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>7.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_SEVILLA = df_CCSEVILLAAM.dropna(how="all",axis=1)
msno.matrix(df_SEVILLA)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>7.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_SEVILLA.iloc[:, 0:8] # Primeras diez columnas
# Out:
#                                             MATRICULA  ORGANIZACION  \
# 0                                                8965           2.0
# 1                                               15236           2.0
# 2                                               16463           2.0
# 3                                               16446           2.0
# 4                                                8366           2.0
# 5                                                6976           2.0
# 6                                               17303           2.0
# 7                                               17083           2.0
# 8                                               16938           2.0
# 9                                               16655           2.0
# 10                                              16591           2.0
# 11                                              16548           2.0
# 12                                              16478           2.0
# ...

# %% [markdown]
# <h3>7.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_SEVILLA.columns)
print("Columnas:",len(df_SEVILLA.columns))
# Out:
# Index(['MATRICULA', 'ORGANIZACION', 'EST-MATRICULA', 'FEC-MATRICULA',
#        'FEC-RENOVACION', 'ULT-ANO_REN', 'DIR-COMERCIAL', 'MUN-COMERCIAL',
#        'CIIU-1', 'CIIU-2', 'CIIU-3', 'CIIU-4', 'ACTIVIDAD', 'MAT-PROP.',
#        'IDE-PROP.', 'NIT-PROP.', 'CAM-PROP.', 'DIR-PROP', 'MUN-PROP'],
#       dtype='object')
# Columnas: 19

# %% [markdown]
# **MATRICULA**
# <br>
# **ORGANIZACION**
# <br>
# **EST-MATRICULA**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **MAT-PROP**
# <br>
# **IDE-PROP**
# <br>
# **NIT-PROP**
# <br>
# **CAM-PROP**
# <br>
# **DIR-PROP**
# <br>
# **MUN-PROP**

# %% [markdown]
# <h2>8. Municipio Tulua - (Municipality Tulua)</h2>
# <h3>8.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_cctuluaAM = pd.read_excel(r"cc tulua A M.xlsx")
msno.matrix(df_cctuluaAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>8.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_tulua = df_cctuluaAM.dropna(how="all",axis=1)
msno.matrix(df_tulua)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>8.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_tulua.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#      MATRICULA  ORGANIZACION  CATEGORIA EST-MATRICULA  EST_DATOS   FECHA-NAC  \
# 0        99992             1          0            MA          6  19920601.0
# 1        99977             1          0            MA          6  19930519.0
# 2        99874             1          0            MA          6  19610812.0
# 3        99846             1          0            MA          6  19891106.0
# 4        99804             1          0            MA          6  19640512.0
# ..         ...           ...        ...           ...        ...         ...
# 366     100351             1          0            MA          6  19850807.0
# 367     100343             1          0            MA          6  19830418.0
# 368     100090             1          0            MA          6         NaN
# 369     100070             1          0            MA          6  19880614.0
# 370     100006             1          0            MA          6  19510417.0
#
#      CLASE-ID IDENTIFICACION
# ...

# %% [markdown]
# <h3>8.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_tulua.columns[100:150])
print("Columnas:",len(df_tulua.columns))
# Out:
# Index(['NOM-PROP', 'DIR-PROP', 'TEL-1-PROP', 'MUN-PROP', 'FEC-PAG-REN 2016',
#        'FEC-PAG-REN 2017', 'FEC-PAG-REN 2018', 'FEC-PAG-REN 2019',
#        'FEC-PAG-REN 2020', 'ACTI 2016', 'ACTI 2017', 'ACTI 2018', 'ACTI 2019',
#        'ACTI 2020', 'NUMALCALDIA', 'TIENELIBROS', 'NUM-SOCIOS', 'REP-LEGAL',
#        'NOM-REP-LEGAL', 'NUM-IDE-SUPLENTE', 'NOMBRE-SUPLENTE', 'REVISORES',
#        'AUT-ENV'],
#       dtype='object')
# Columnas: 123

# %% [markdown]
# **MATRICULA**
# <br>
# **ORGANIZACION**
# <br>
# **CATEGORIA**
# <br>
# **EST-MATRICULA**
# <br>
# **EST_DATOS**
# <br>
# **FECHA-NAC**
# <br>
# **CLASE-ID**
# <br>
# **IDENTIFICACION**
# <br>
# **GENERO**
# <br>
# **NIT**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **FEC-CONSTITUCION**
# <br>
# **FEC-DISOLUCION**
# <br>
# **FEC-LIQUIDACION**
# <br>
# **FEC-VIGENCIA**
# <br>
# **DIR-COMERCIAL**
# <br>
# **BARRIO-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **VIGILANCIA**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **CANT-MUJERES**
# <br>
# **CANT-MUJERES-CAR-DIR**
# <br>
# **%-PART-MUJ**
# <br>
# **CIIU-TAM-EMPRESARIAL**
# <br>
# **ING-TAM-EMPRESARIAL**
# <br>
# **ANO-DATOS-TAM-EMPRESARIAL**
# <br>
# **FECHA-DATOS-TAM-EMPRESARIAL**
# <br>
# **LIBROS-COMERCIO**
# <br>
# **CTR-EMBARGO**
# <br>
# **IMPORTA-EXPORTA**
# <br>
# **TIPO-LOCAL**
# <br>
# **UBICACION**
# <br>
# **CLA-ECON-SOLI**
# <br>
# **BEN-ART-7**
# <br>
# **BEN-LEY-1780(MAT)**
# <br>
# **CUM-LEY-1780(REN)**
# <br>
# **MAN-LEY-1780(REN)**
# <br>
# **REN-LEY-1780(REN)**
# <br>
# **TIPO-PROPIEDAD**
# <br>
# **BIC-LEY-1901-2018**
# <br>
# **TAM-EMPRESA**
# <br>
# **PERSONAL**
# <br>
# **ACTIVO-CORRIENTE**
# <br>
# **ACTIVO-NO-CORRIENTE**
# <br>
# **ACTIVO-FIJO**
# <br>
# **ACTIVO-VALORIZ**
# <br>
# **ACTIVO-OTROS**
# <br>
# **ACTIVO-TOTAL**
# <br>
# **PASIVO-CORRIENTE**
# <br>
# **PASIVO-LRG-PLAZO**
# <br>
# **PASIVO-TOTAL**
# <br>
# **PATRIMONIO**
# <br>
# **PASIVO+PATRIM**
# <br>
# **ING-OPERACIONES**
# <br>
# **ING-NO-OPERACIONALES**
# <br>
# **GAS-OPERACIONALES**
# <br>
# **GAS-NO-OPERAC.**
# <br>
# **COS-VEN**
# <br>
# **GAS-IMP**
# <br>
# **UTIL-OPERACIONAL**
# <br>
# **UTIL-NETA**
# <br>
# **GRUPO-NIIF**
# <br>
# **ANIO-DATOS**
# <br>
# **FECHA-DATOS**
# <br>
# **CAPITAL-AUTORIZ**
# <br>
# **CAPITAL-SUSCRITO**
# <br>
# **CAPITAL-PAGADO**
# <br>
# **CAPITAL-SOCIAL**
# <br>
# **APORTE-LABORAL**
# <br>
# **APORTE-LABORAL-ADI**
# <br>
# **APORTE-DINERO**
# <br>
# **APORTE-TRABAJO**
# <br>
# **APORTE-ACTIVOS**
# <br>
# **APORTE-TOTAL**
# <br>
# **VLR-ESTABLEC**
# <br>
# **PATRIM-ESADL**
# <br>
# **CANT-EST-BD**
# <br>
# **POR-NAL-PRI**
# <br>
# **POR-NAL-PUB**
# <br>
# **POR-NAL-TOT**
# <br>
# **POR-EXT-PRI**
# <br>
# **POR-EXT-PUB**
# <br>
# **POR-EXT-TOT**
# <br>
# **CTR-AFILIACION**
# <br>
# **ANIO-REN-AFIL**
# <br>
# **FEC-ULT-PAG-AFIL**
# <br>
# **VAL-ULT-PAG-AFIL**
# <br>
# **FEC-ACTA-CAN-AFLIA**
# <br>
# **MAT-PROP**
# <br>
# **IDE-PROP**
# <br>
# **NIT-PROP**
# <br>
# **CAM-PROP**
# <br>
# **NOM-PROP**
# <br>
# **DIR-PROP**
# <br>
# **TEL-1-PROP**
# <br>
# **MUN-PROP**
# <br>
# **FEC-PAG-REN 2016**
# <br>
# **FEC-PAG-REN 2017**
# <br>
# **FEC-PAG-REN 2018**
# <br>
# **FEC-PAG-REN 2019**
# <br>
# **FEC-PAG-REN 2020**
# <br>
# **ACTI 2016**
# <br>
# **ACTI 2017**
# <br>
# **ACTI 2018**
# <br>
# **ACTI 2019**
# <br>
# **ACTI 2020**
# <br>
# **NUMALCALDIA**
# <br>
# **TIENELIBROS**
# <br>
# **NUM-SOCIOS**
# <br>
# **REP-LEGAL**
# <br>
# **NOM-REP-LEGAL**
# <br>
# **NUM-IDE-SUPLENTE**
# <br>
# **NOMBRE-SUPLENTE**
# <br>
# **REVISORES**
# <br>
# **AUT-ENV**

# %% [markdown]
# <h2>9. Contribución al Deporte - (Disbursement to sport)</h2>
# <h3>9.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_contribucionAM = pd.read_excel(r"contribucion  A M.xlsx")
msno.matrix(df_contribucionAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>9.2 Eliminación de Datos NAN - (Removal of NAN Data)
# </h3>

# %%
df_contribucion = df_contribucionAM.dropna(how="all",axis=1)
msno.matrix(df_contribucion)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>9.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_contribucion.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#             NIT        NUMERO  \
# 0      htt#etrt  7.601002e+13
# 1      htt#etrt  7.601002e+13
# 2      htt#etrt  7.601002e+13
# 3      htt#etrt  7.601002e+13
# 4      htt#etrt  7.601002e+13
# ...         ...           ...
# 21806  e3:br::3  7.601002e+13
# 21807  e3:br::3  7.601002e+13
# 21808  e3:br::3  7.601002e+13
# 21809  e3:br::3  7.601002e+13
# 21810  e3:br::3  7.601002e+13
#
#                                              DESCRIPCION     TOTAL  \
# 0      DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...    8000.0
# 1      DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...    8000.0
# 2      DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...    8000.0
# 3      DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...    8000.0
# 4      DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...    8000.0
# ...                                                  ...       ...
# 21806  DECLARACIÃ“N DE LA CONTRIBUCIÃ“N PARA EL DEPOR...  198000.0
# ...

# %% [markdown]
# <h3>9.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_contribucion.columns)
print("Columnas:",len(df_contribucion.columns))
# Out:
# Index(['NIT', 'NUMERO', 'DESCRIPCION', 'TOTAL', 'FCHA_RCDO', 'CNSCTVO_BNCO',
#        'BANCO', 'ESTADO', 'SUCURSAL', 'PRDO_GRVBLE_ANO', 'PRDO_GRVBLE_MES',
#        'CDGO_DPRTMNTO', 'DSCRPCN_DPRTMNTO', 'CDGO_MNCPO', 'DSCRPCN_MNCPO',
#        'DRCCN', 'PRMR_APLLDO_USRO', 'DSCRPCN_IMPSTO', 'ORDEN'],
#       dtype='object')
# Columnas: 19

# %% [markdown]
# **NIT**
# <br>
# **NUMERO**
# <br>
# **DESCRIPCION**
# <br>
# **TOTAL**
# <br>
# **FCHA_RCDO**
# <br>
# **CNSCTVO_BNCO**
# <br>
# **BANCO**
# <br>
# **ESTADO**
# <br>
# **SUCURSAL**
# <br>
# **PRDO_GRVBLE_ANO**
# <br>
# **PRDO_GRVBLE_MES**
# <br>
# **CDGO_DPRTMNTO**
# <br>
# **DSCRPCN_DPRTMNTO**
# <br>
# **CDGO_MNCPO**
# <br>
# **DSCRPCN_MNCPO**
# <br>
# **DRCCN**
# <br>
# **PRMR_APLLDO_USRO**
# <br>
# **DSCRPCN_IMPSTO**
# <br>
# **ORDEN**

# %% [markdown]
# <h2>10. Licores - (Alcohol)</h2>
# <h3>10.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_DECLARACIONNaleImportado2015al2019AM = pd.read_excel(r"DECLARACION Nal e Importado 2015 al 2019  AM.xlsx")
msno.matrix(df_DECLARACIONNaleImportado2015al2019AM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>10.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_Licores = df_DECLARACIONNaleImportado2015al2019AM.dropna(how="all",axis=1)
msno.matrix(df_Licores)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>10.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_Licores.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#       Unnamed: 0 Unnamed: 1       DECLARACIONES POR PRODUCTOS (IMPORTADOS)  \
# 0            NaN        NaN                                            NaN
# 1            NaN        NaN                                        CLASE:
# 2            NaN        NaN  FECHA DE GENERACION: 21/08/2020 3:03:21 p. m.
# 3            NaN        NaN                                            NaN
# 4            año     CODIGO                                         ORIGEN
# ...          ...        ...                                            ...
# 17464       2019   11007109                                              1
# 17465       2019   11010472                                              1
# 17466       2019   11007128                                              1
# 17467       2019   11006489                                              1
# 17468       2019   11006488                                              1
#
#                                    Unnamed: 3     Unnamed: 4  \
# ...

# %% [markdown]
# <h3>10.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_Licores.columns)
print("Columnas:",len(df_Licores.columns))
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'DECLARACIONES POR PRODUCTOS (IMPORTADOS)',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21'],
#       dtype='object')
# Columnas: 21

# %% [markdown]
# **año**
# <br>
# **CODIGO**
# <br>
# **ORIGEN**
# <br>
# **NOMB_PRO**
# <br>
# **TIPO_PRODCUTO**
# <br>
# **NIT**
# <br>
# **CLASE**
# <br>
# **TIPO**
# <br>
# **UNIDADES**
# <br>
# **PRESENTACION**
# <br>
# **GRADOS**
# <br>
# **IMPUESTO_DECLARADO**
# <br>
# **IMPUESTO_PARTICIPACION**
# <br>
# **UNIDADES_CAPACIDAD**
# <br>
# **IMPUESTO_REENVIADO**
# <br>
# **UNIDADES_REENVIOS_CAPACIDAD**
# <br>
# **UNIDAD_CONVERTIDAS**
# <br>
# **SOBRETASA_DECLARADA**
# <br>
# **UNIDADES_REENVIOS_CONVERTIDAS**
# <br>
# **SOBRETASA_REENVIADA**
# <br>
# **CODI_DANE**

# %% [markdown]
# <h2>11. Deguello</h2>
# <h3>11.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_deguelloAM= pd.read_excel(r"deguello  A M.xlsx")
msno.matrix(df_deguelloAM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>11.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_deguello = df_deguelloAM.dropna(how="all",axis=1)
msno.matrix(df_deguello)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>11.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_deguello.iloc[:, 0:8]
# Out:
#             NIT          NUMERO  \
# 0     3tthtt(h&  76010006003247
# 1     3tthtt(h&  76010006003247
# 2     3tthtt(h&  76010006003275
# 3     3tthtt(h&  76010006003275
# 4     3tthtt(h&  76010006003300
# ...         ...             ...
# 1575  e&(h#&&&&  76010006003750
# 1576  e&(h#&&&&  76010006003740
# 1577  e&(h#&&&&  76010006003733
# 1578  e&(h#&&&&  76010006003742
# 1579  e&(h#&&&&  76010006003738
#
#                                             DESCRIPCION    TOTAL FCHA_RCDO  \
# 0     DECLARACIÃ“N DEL IMPUESTO DE DEGÃœELLO DE GANA...  1845000       NaN
# 1     DECLARACIÃ“N DEL IMPUESTO DE DEGÃœELLO DE GANA...  1845000       NaN
# 2     DECLARACIÃ“N DEL IMPUESTO DE DEGÃœELLO DE GANA...  2340000       NaN
# 3     DECLARACIÃ“N DEL IMPUESTO DE DEGÃœELLO DE GANA...  2340000       NaN
# 4     DECLARACIÃ“N DEL IMPUESTO DE DEGÃœELLO DE GANA...  3448000       NaN
# ...                                                 ...      ...       ...
# ...

# %% [markdown]
# <h3>11.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_deguello.columns)
print("Columnas:",len(df_deguello.columns))
# Out:
# Index(['NIT', 'NUMERO', 'DESCRIPCION', 'TOTAL', 'FCHA_RCDO', 'CNSCTVO_BNCO',
#        'BANCO', 'ESTADO', 'SUCURSAL', 'PRDO_GRVBLE_ANO', 'PRDO_GRVBLE_MES',
#        'CDGO_DPRTMNTO', 'DSCRPCN_DPRTMNTO', 'CDGO_MNCPO', 'DSCRPCN_MNCPO',
#        'DRCCN', 'PRMR_NMBR_USRO', 'DSCRPCN_IMPSTO', 'ORDEN'],
#       dtype='object')
# Columnas: 19

# %% [markdown]
# **NIT**
# <br>
# **NUMERO**
# <br>
# **DESCRIPCION**
# <br>
# **TOTAL**
# <br>
# **FCHA_RCDO**
# <br>
# **CNSCTVO_BNCO**
# <br>
# **BANCO**
# <br>
# **ESTADO**
# <br>
# **SUCURSAL**
# <br>
# **PRDO_GRVBLE_ANO**
# <br>
# **PRDO_GRVBLE_MES**
# <br>
# **CDGO_DPRTMNTO**
# <br>
# **DSCRPCN_DPRTMNTO**
# <br>
# **CDGO_MNCPO**
# <br>
# **DSCRPCN_MNCPO**
# <br>
# **DRCCN**
# <br>
# **PRMR_NMBR_USRO**
# <br>
# **DSCRPCN_IMPSTO**
# <br>
# **ORDEN**

# %% [markdown]
# <h2>12. Rentas 240 - (Income 240)</h2>
# <h3>12.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_form240AM = pd.read_excel(r"form 240 AM.xlsx")
msno.matrix(df_form240AM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>12.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_240 = df_form240AM.dropna(how="all",axis=1)
msno.matrix(df_240 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>12.3 Visualización de Datos- (Data visualization)</h3>

# %%
df_240.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#       Año Gravable  Número Nit  Código Departamento  Código Municipio  \
# 0             2016    b3:&b3:(                   76             76001
# 1             2016    :rthht((                   76             76001
# 2             2016    bhe3re:h                   76             76001
# 3             2016    h:rrhb(3                   76             76001
# 4             2016    ::e::hh#                   76             76001
# ...            ...         ...                  ...               ...
# 2894          2016    e&#3t3:h                   76             76834
# 2895          2016     :&e3h#(                   76             76834
# 2896          2016     #:bh&#&                   76             76834
# 2897          2016    :bbh#&he                   76             76834
# 2898          2016  hhh:#rh#bt                   76             76834
#
#       Código Actividad Económica Principal  Total Patrimonio Bruto (55)  \
# ...

# %% [markdown]
# <h3>12.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_240 .columns)
print("Columnas:",len(df_240 .columns))
# Out:
# Index(['Año Gravable', 'Número Nit', 'Código Departamento', 'Código Municipio',
#        'Código Actividad Económica Principal', 'Total Patrimonio Bruto (55)',
#        'RGA IMAS T-Ingresos brutos trabajador cuenta propia (743)',
#        'RGA IMAS T-Otros ingresos (744)',
#        'RGA IMAS T-Ingresos excluidos de la base (745)',
#        'RGA IMAS T-Total ingresos Renta (746)',
#        'RGA IMAS T- Devolución rebajas descuentos trabajador cuenta propia (747)',
#        'RGA IMAS T-Total ingresos netos (748)'],
#       dtype='object')
# Columnas: 12

# %% [markdown]
# **Año Gravable**
# <br>
# **Número Nit**
# <br>
# **Código Departamento**
# <br>
# **Código Municipio**
# <br>
# **Código Actividad Económica Principal**
# <br>
# **Total Patrimonio Bruto (55)**
# <br>
# **RGA IMAS T-Ingresos brutos trabajador cuenta propia (743)**
# <br>
# **RGA IMAS T-Otros ingresos (744)**
# <br>
# **RGA IMAS T-Ingresos excluidos de la base (745)**
# <br>
# **RGA IMAS T-Total ingresos Renta (746)**
# <br>
# **RGA IMAS T- Devolución rebajas descuentos trabajador cuenta propia (747)**
# <br>
# **RGA IMAS T-Total ingresos netos (748)**

# %% [markdown]
# <h2>13. Formato 110 - (Format 110)</h2>
# <h3>13.1 Distribución de Valores Faltantes
#  - (Distribution of Missing Values)</h3>

# %%
df_formato110AM = pd.read_excel(r"formato 110 AM.xlsx")
msno.matrix(df_formato110AM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>13.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_110 = df_formato110AM.dropna(how="all",axis=1)
msno.matrix(df_110 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>13.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_110.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#         Año Gravable  Número Nit  Código Departamento  Código Municipio  \
# 0             2016.0   ettrh:3&3                 76.0           76001.0
# 1             2016.0   etthb&((b                 76.0           76001.0
# 2             2016.0   etttrh#h(                 76.0           76001.0
# 3             2016.0   3etb#r((b                 76.0           76001.0
# 4             2016.0   ettt:&hrh                 76.0           76001.0
# ...              ...         ...                  ...               ...
# 155903        2018.0   ett:rb:&t                 76.0           76834.0
# 155904        2016.0  hhh:#(#hth                 76.0           76834.0
# 155905        2017.0   ett3hbe3:                 76.0           76834.0
# 155906        2016.0    ::r#3e&t                 76.0           76834.0
# 155907        2016.0     :h&:#3#                 76.0           76834.0
#
#         Código Actividad Económica Principal  \
# 0                                     4631.0
# ...

# %% [markdown]
# <h3>13.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_110.columns)
print("Columnas:",len(df_110.columns))
# Out:
# Index(['Año Gravable', 'Número Nit', 'Código Departamento', 'Código Municipio',
#        'Código Actividad Económica Principal',
#        'Devoluciones Rebajas y Descuentos en Ventas (120)',
#        'Ingresos Brutos no Operacionales (335)',
#        'Ingresos brutos de actividades Ordinarias (334)',
#        'Ingresos no Constitutivos de Renta (338)',
#        'Intereses y Rendimientos Financieros (96)',
#        'Total Ingresos Brutos (462)', 'Total Ingresos Netos (459)',
#        'Ingresos financieros (3911)',
#        'Dividendos y/o partic rec o capítalizados por soc extr (año 2016 y anteriores) o nac cualquier año (3912)',
#        'Dividendos y/o participaciones recibidos decla diferentes soc nacionales, años 2017 y siguientes (3913)',
#        'Dividendos y/o participaciones recibidos por Pers Nat sin residencia fiscal (2016 y anteriores) (3914)',
#        'Otros ingresos (3915)',
# ...

# %% [markdown]
# **Año Gravable**
# <br>
# **Número Nit**
# <br>
# **Código Departamento**
# <br>
# **Código Municipio**
# <br>
# **Código Actividad Económica Principal**
# <br>
# **Devoluciones Rebajas y Descuentos en Ventas (120)**
# <br>
# **Ingresos Brutos no Operacionales (335)**
# <br>
# **Ingresos brutos de actividades Ordinarias (334)**
# <br>
# **Ingresos no Constitutivos de Renta (338)**
# <br>
# **Intereses y Rendimientos Financieros (96)**
# <br>
# **Total Ingresos Brutos (462)**
# <br>
# **Total Ingresos Netos (459)**
# <br>
# **Ingresos financieros (3911)**
# <br>
# **Dividendos y/o partic rec o capítalizados por soc extr (año 2016 y anteriores) o nac cualquier año (3912)**
# <br>
# **Dividendos y/o participaciones recibidos decla diferentes soc nacionales, años 2017 y siguientes (3913)**
# <br>
# **Dividendos y/o participaciones recibidos por Pers Nat sin residencia fiscal (2016 y anteriores) (3914)**
# <br>
# **Otros ingresos (3915)**
# <br>
# **Ingr no constitutivos renta dividendos y/o part PersNat sin residencia fiscal (2016 y anteriores) (3916)**

# %% [markdown]
# <h2>14. Formato 210 - (Format 210)</h2>
# <h3>14.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_formato210AM = pd.read_excel(r"formato 210 A M.xlsx")
msno.matrix(df_formato210AM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>14.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_210  = df_formato210AM.dropna(how="all",axis=1)
msno.matrix(df_210 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>14.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_210.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#         Año Gravable Número Nit  Código Departamento  Código Municipio  \
# 0               2016   #eBr&&Be                 76.0           76001.0
# 1               2018   Bh3r:(hB                 76.0           76001.0
# 2               2018   e&&e:etr                 76.0           76001.0
# 3               2018   Brt3B:tr                 76.0           76001.0
# 4               2018   B3e&#:he                 76.0           76001.0
# ...              ...        ...                  ...               ...
# 337786          2018   Bh#t(er#                 76.0           76001.0
# 337787          2017   h:(&3#:e                 76.0           76001.0
# 337788          2018   h&:r:h#&                 76.0           76001.0
# 337789          2018   Bh&:33:B                 76.0           76001.0
# 337790          2018   h:r(B3:h                 76.0           76001.0
#
#         Código Actividad Económica Principal  Honorarios  \
# ...

# %% [markdown]
# <h3>14.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_210.columns[0:11])
print("Columnas:",len(df_210.columns))
# Out:
# Index(['Año Gravable', 'Número Nit', 'Código Departamento', 'Código Municipio',
#        'Código Actividad Económica Principal', 'Honorarios',
#        'Ingresos no Constitutivos de Renta (338)',
#        'Intereses y Rendimientos Financieros (96)',
#        'Otros Ingresos (Arrendamientos etc.) (97)',
#        'Salarios y Demás Pagos Laborales (102)',
#        'Ingresos como Empleado (99)'],
#       dtype='object')
# Columnas: 34

# %% [markdown]
# **Año Gravable**
# <br>
# **Número Nit**
# <br>
# **Código Departamento**
# <br>
# **Código Municipio**
# <br>
# **Código Actividad Económica Principal**
# <br>
# **Honorarios**
# <br>
# **Ingresos no Constitutivos de Renta (338)**
# <br>
# **Intereses y Rendimientos Financieros (96)**
# <br>
# **Otros Ingresos (Arrendamientos etc.) (97)**
# <br>
# **Salarios y Demás Pagos Laborales (102)**
# <br>
# **Ingresos como Empleado (99)**
# <br>
# **Ingresos Pension jubilación invalidez vejez sobreviviente riesgos laborales (98)**
# <br>
# **Ingresos Dividendos y Participaciones (94)**
# <br>
# **Ingresos en el Exterior (84)**
# <br>
# **Total Ingresos Brutos (462)**
# <br>
# **Total Ingresos Netos (459)**
# <br>
# **INCRNGO Dividendos y participaciones (71)**
# <br>
# **INCRNGO Pagos a terceros (Salud)**
# <br>
# **educación y alimentación) (73)**
# <br>
# **INCRNGO Pagos a terceros Alimentación (48)**
# <br>
# **Otros ingresos INCRNGO no constitutivos de renta ni ganacia ocasional (74)**
# <br>
# **Total ingresos INCRNGO no constitutivos de renta ni ganacia ocasional (456)**
# <br>
# **Ingresos brutos por rentas de trabajo (art 103 E.T.) (3994)**
# <br>
# **Ingresos Obtenidos en el exterior por renta de trabajo (4101)**
# <br>
# **Ingresos no constitutivos de renta por renta de trabajo (4104)**
# <br>
# **Ingresos del Exterior por Rentas de Capital (3858)**
# <br>
# **Total ingresos rentas de capital (3859)**
# <br>
# **Ingresos no constitutivos de renta por renta de capital (4106)**
# <br>
# **Ingresos No laborales (3866)**
# <br>
# **Honorarios diferentes a los de rentas de trabajo (3867)**
# <br>
# **Ingresos del exterior por rentas no laborales (3868)**
# <br>
# **Total ingresos rentas no laborales (3869)**
# <br>
# **Ingresos no constitutivos de renta por renta No laborales (4107)**
# <br>
# **Ingresos por Pensiones (3852)**

# %% [markdown]
# <h2>15. Formato 230 - (Format 230)</h2>
# <h3>15.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_formato230AM = pd.read_excel(r"formato 230 AM.xlsx")
msno.matrix(df_formato230AM)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>15.2 Eliminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_230 = df_formato230AM.dropna(how="all",axis=1)
msno.matrix(df_230 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>15.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_230.iloc[:, 0:8] # Primeras ocho columnas
# Out:
#        Año Gravable Número Nit  Código Departamento  Código Municipio  \
# 0              2016   e&&tt3(h                   76             76001
# 1              2016   b3(e((:3                   76             76001
# 2              2016   e&&&rb(h                   76             76001
# 3              2016   h&&&&t3&                   76             76001
# 4              2016   e&&t#t(r                   76             76001
# ...             ...        ...                  ...               ...
# 32481          2016   e&b:::h(                   76             76834
# 32482          2016   hh###3h(                   76             76520
# 32483          2016   h:#reh#e                   76             76520
# 32484          2016   b3re&hbr                   76             76834
# 32485          2016   ::rhr3tt                   76             76834
#
#        Código Actividad Económica Principal  Total Patrimonio Bruto (55)  \
# ...

# %% [markdown]
# <h3>15.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_230.columns)
print("Columnas:",len(df_230.columns))
# Out:
# Index(['Año Gravable', 'Número Nit', 'Código Departamento', 'Código Municipio',
#        'Código Actividad Económica Principal', 'Total Patrimonio Bruto (55)',
#        'RGA IMAS-Ingresos brutos del empleado (724)',
#        'RGA IMAS-Otros ingresos (725)',
#        'RGA IMAS-Ingresos excluidos base (726)',
#        'RGA IMAS-Total ingresos (727)'],
#       dtype='object')
# Columnas: 10

# %% [markdown]
# **Año Gravable**
# <br>
# **Número Nit**
# <br>
# **Código Departamento**
# <br>
# **Código Municipio**
# <br>
# **Código Actividad Económica Principal**
# <br>
# **Total Patrimonio Bruto (55)**
# <br>
# **RGA IMAS-Ingresos brutos del empleado (724)**
# <br>
# **RGA IMAS-Otros ingresos (725)**
# <br>
# **RGA IMAS-Ingresos excluidos base (726)**
# <br>
# **RGA IMAS-Total ingresos (727)**

# %% [markdown]
# <h2>16. Loterias - Lottery</h2>
# <h3>16.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_loterias_A_M = pd.read_excel(r"loterias  A M.xlsx")
msno.matrix(df_loterias_A_M)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>16.2 Eliminación de Datos NAN - (Removal of NAN Data)
# </h3>

# %%
df_loterias = df_loterias_A_M.dropna(how="all",axis=1)
msno.matrix(df_loterias)

# %% [markdown]
# <h3>16.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_loterias .iloc[:, 0:8] # Primeras ocho columnas

# %% [markdown]
# <h3>16.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_loterias.columns)
print("Columnas:",len(df_loterias.columns))

# %% [markdown]
# **NIT**
# <br>
# **NUMERO**
# <br>
# **DESCRIPCION**
# <br>
# **TOTAL**
# <br>
# **ESTADO**
# <br>
# **PRDO_GRVBLE_ANO**
# <br>
# **PRDO_GRVBLE_MES**
# <br>
# **CDGO_DPRTMNTO**
# <br>
# **DSCRPCN_DPRTMNTO**
# <br>
# **CDGO_MNCPO**
# <br>
# **DSCRPCN_MNCPO**
# <br>
# **DRCCN**
# <br>
# **PRMR_NMBR_USRO**
# <br>
# **DSCRPCN_IMPSTO**
# <br>
# **ORDEN**

# %% [markdown]
# <h2>17. Relación de Ventas - sales relation</h2>
# <h3>17.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_RELACIONDEVEntasyPD2015AL2019am = pd.read_excel(r"RELACION DE VEntas y PD 2015 AL 2019 a m.xlsx")
msno.matrix(df_RELACIONDEVEntasyPD2015AL2019am)

# %% [markdown]
# <h3>17.2 Eminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_RELACIONDEVEntasyPD2015AL2019 = df_RELACIONDEVEntasyPD2015AL2019am.dropna(how="all",axis=1)
msno.matrix(df_RELACIONDEVEntasyPD2015AL2019)

# %% [markdown]
# <h3>17.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_RELACIONDEVEntasyPD2015AL2019.iloc[:, 0:8] # Primeras ocho columnas

# %% [markdown]
# <h3>17.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_RELACIONDEVEntasyPD2015AL2019.columns)
print("Columnas:",len(df_RELACIONDEVEntasyPD2015AL2019.columns))

# %% [markdown]
# **ANNO**
# <br>
# **TIPO_MOVIMIENTO**
# <br>
# **NIT**
# <br>
# **NRO_MOVIMIENTO**
# <br>
# **PRODUCTO**
# <br>
# **CAPACIDAD**
# <br>
# **ORIGEN**
# <br>
# **RENGLON_DPT**
# <br>
# **CANTIDAD**
# <br>
# **FONDO_CUENTA**
# <br>
# **NRO_RENGLON**
# <br>
# **DECLARACION**
# <br>
# **IMPUESTO**
# <br>
# **PARTICIPACION**
# <br>
# **EXCEDENTE**
# <br>
# **IMP_UNIDAD**
# <br>
# **TG_REENVIO**
# <br>
# **SANCIONES**
# <br>
# **SOBRETASA**
# <br>
# **NOTA**
# <br>
# **FACTURA**
# <br>
# **FECHA_MOVIMIENTO**
# <br>
# **CIUDAD_ORIGEN**
# <br>
# **CIUDAD_DESTINO**
# <br>
# **CLASE_PRODUCTO**
# <br>
# **PLANTA**

# %% [markdown]
# <h2>18. Sevilla PYG - (Municipality Sevilla PYG)</h2>
# <h3>18.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_sevillaconAMconpyg = pd.read_excel(r"sevilla con A M  con pyg.xlsx")
msno.matrix(df_sevillaconAMconpyg)

# %% [markdown]
# <h3>18.2 Eminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_sevillaconAMconpyg = df_sevillaconAMconpyg.dropna(how="all",axis=1)
msno.matrix(df_sevillaconAMconpyg)

# %% [markdown]
# <h3>18.3 Visualización de Datos - (Data visualization)v</h3>

# %%
df_sevillaconAMconpyg.iloc[:, 0:8] # Primeras ocho columnas

# %% [markdown]
# <h3>18.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_sevillaconAMconpyg.columns[0:11])
print("Columnas:",len(df_sevillaconAMconpyg.columns))

# %% [markdown]
# **MATRICULA**
# <br>
# **ORGANIZACION**
# <br>
# **EST-MATRICULA**
# <br>
# **FEC-MATRICULA**
# <br>
# **FEC-RENOVACION**
# <br>
# **ULT-ANO_REN**
# <br>
# **DIR-COMERCIAL**
# <br>
# **MUN-COMERCIAL**
# <br>
# **TEL-COM-3**
# <br>
# **DIR-NOTIFICACION**
# <br>
# **MUN-NOTIFICACION**
# <br>
# **TEL-NOTF-1**
# <br>
# **TEL-NOTF-2**
# <br>
# **CIIU-1**
# <br>
# **CIIU-2**
# <br>
# **CIIU-3**
# <br>
# **CIIU-4**
# <br>
# **ACTIVIDAD**
# <br>
# **TIPO-PROPIEDAD**
# <br>
# **PERSONAL**
# <br>
# **ACTIVO-CORRIENTE**
# <br>
# **ACTIVO-NO-CORRIENTE**
# <br>
# **ACTIVO-FIJO**
# <br>
# **ACTIVO-VALORIZ**
# <br>
# **ACTIVO-OTROS**
# <br>
# **ACTIVO-TOTAL**
# <br>
# **PASIVO-CORRIENTE**
# <br>
# **PASIVO-LRG-PLAZO**
# <br>
# **PASIVO-TOTAL**
# <br>
# **PATRIMONIO**
# <br>
# **PASIVO+PATRIM**
# <br>
# **ING-OPERACIONES**
# <br>
# **ING-NO-OPERACIONALES**
# <br>
# **GAS-OPERACIONALES**
# <br>
# **GAS-NO-OPERAC.**
# <br>
# **COS-VEN.**
# <br>
# **GAS-IMP.**
# <br>
# **UTIL-OPERACIONAL**
# <br>
# **UTIL-NETA**
# <br>
# **ANIO-DATOS**
# <br>
# **FECHA-DATOS**
# <br>
# **VLR-ESTABLEC.**
# <br>
# **MAT-PROP.**
# <br>
# **IDE-PROP.**
# <br>
# **NIT-PROP.**
# <br>
# **CAM-PROP.**
# <br>
# **DIR-PROP**
# <br>
# **MUN-PROP**

# %% [markdown]
# <h2>19. Gasolina - (Fuel)</h2>
# <h3>19.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_sobretasaalagasolinaAM= pd.read_excel(r"sobretasa a la gasolina  A M.xlsx")
msno.matrix(df_sobretasaalagasolinaAM)

# %% [markdown]
# <h3>19.2 Eminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_gasolina = df_sobretasaalagasolinaAM.dropna(how="all",axis=1)
msno.matrix(df_gasolina)

# %% [markdown]
# <h3>19.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_gasolina.iloc[:, 0:8] # Primeras ocho columnas

# %% [markdown]
# <h3>19.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_gasolina.columns)
print("Columnas:",len(df_gasolina.columns))

# %% [markdown]
# **NIT**
# <br>
# **RAZON**
# <br>
# **NUMERO**
# <br>
# **DESCRIPCION**
# <br>
# **TOTAL**
# <br>
# **FCHA_RCDO**
# <br>
# **CNSCTVO_BNCO**
# <br>
# **BANCO**
# <br>
# **ESTADO**
# <br>
# **SUCURSAL**
# <br>
# **PRDO_GRVBLE_ANO**
# <br>
# **PRDO_GRVBLE_MES**
# <br>
# **CDGO_DPRTMNTO**
# <br>
# **DSCRPCN_DPRTMNTO**
# <br>
# **CDGO_MNCPO**
# <br>
# **DSCRPCN_MNCPO**
# <br>
# **DRCCN**
# <br>
# **PRMR_NMBR_USRO**
# <br>
# **DSCRPCN_IMPSTO**
# <br>
# **ORDEN**

# %% [markdown]
# <h2>20. Ventas 300 - (Sales 300)</h2>
# <h3>20.1 Distribución de Valores Faltantes - (Distribution of Missing Values)</h3>

# %%
df_ventas300AM = pd.read_excel(r"ventas 300 A M.xlsx")
msno.matrix(df_ventas300AM)

# %% [markdown]
# <h3>20.2 Eminación de Datos NAN - (Removal of NAN Data)</h3>

# %%
df_ventas300 = df_ventas300AM.dropna(how="all",axis=1)
msno.matrix(df_ventas300)

# %% [markdown]
# <h3>20.3 Visualización de Datos - (Data visualization)</h3>

# %%
df_ventas300AM.iloc[:, 0:8] # Primeras ocho columnas

# %% [markdown]
# <h3>20.4 Columnas del DataFrame - (Dataframe Columns)</h3>

# %%
print(df_ventas300AM.columns[0:11])
print("Columnas:",len(df_ventas300AM.columns))

# %% [markdown]
# **Año Gravable**
# <br>
# **Número Nit**
# <br>
# **Unnamed: 2**
# <br>
# **Código Departamento**
# <br>
# **Código Municipio**
# <br>
# **Código Actividad Económica Principal**
# <br>
# **Ingresos Por operaciones gravadas al 5 % (233)**
# <br>
# **Ingresos A.I.U por operaciones gravadas (234)**
# <br>
# **Ingresos Por exportación de bienes (235)**
# <br>
# **Ingresos Por exportación de servicios (236)**
# <br>
# **Ingreso Por venta a sociedad comercialización internacional (237)**
# <br>
# **Ingresos Por ventas a Zonas Francas (238)**
# <br>
# **Ingresos Por juegos de suerte y azar (239)**
# <br>
# **Ingresos Por venta de cerveza nacional o importada (240)**
# <br>
# **Ingresos por venta de gaseosas y similares (4087)**
# <br>
# **Ingresos Brutos por Exportaciones (408)**
# <br>
# **Ingresos Brutos por Operaciones Excluidas (295)**
# <br>
# **Ingresos Brutos por Operaciones Exentas (177)**
# <br>
# **Ingresos Brutos por Operaciones Gravadas (139)**
# <br>
# **Ingresos Brutos por Operaciones no Gravadas (379)**
# <br>
# **Menos: Devoluciones Ventas Anuladas**
# <br>
# **Rescindidas y Resueltas (180)**
# <br>
# **Total Ingresos Brutos (462)**
# <br>
# **Total Ingresos Netos (459)**
# <br>
# **vinos y similares (452)**
# <br>
# **Unnamed: 27**
